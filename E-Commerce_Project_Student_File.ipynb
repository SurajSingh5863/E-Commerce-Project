# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %%
# Print the first 10 records
print("First 10 records:")
print(ECom_Data.head(10))

# Print the last 10 records
print("\nLast 10 records:")
print(ECom_Data.tail(10))
# Out:
# First 10 records:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %% [markdown]
# #### Ans 1 b)

# %%
# Get the number of rows and columns
# Method 1: Using shape attribute
num_rows, num_columns = ECom_Data.shape

print("Method 1 - Number of rows:", num_rows)
print("Method 1 - Number of columns:", num_columns)

# Method 2: Using len() function
num_rows = len(ECom_Data)
num_columns = len(ECom_Data.columns)

print("Method 2 - Number of rows:", num_rows)
print("Method 2 - Number of columns:", num_columns)
# Out:
# Method 1 - Number of rows: 8906
# Method 1 - Number of columns: 17
# Method 2 - Number of rows: 8906
# Method 2 - Number of columns: 17

# %% [markdown]
# #### Ans  1 c)

# %%
# Get columns with 'object' data type
object_columns = ECom_Data.select_dtypes(include=['object'])

num_object_columns = len(object_columns.columns)

print("Number of columns with 'object' data type:", num_object_columns)
# Out:
# Number of columns with 'object' data type: 14

# %% [markdown]
# ### Ans 1 d)

# %%
# Get columns with 'bool' data type
bool_columns = ECom_Data.select_dtypes(include=['bool'])

if bool_columns.empty:
    print("No boolean columns found in the DataFrame.")
else:
    print("Boolean columns:", bool_columns.columns.tolist())
# Out:
# No boolean columns found in the DataFrame.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
# Drop the columns
data1 = ECom_Data.drop(columns=['product_specifications', 'description'])

# %% [markdown]
# ### Ans 2 b)

# %%
# Permanently drop the columns by using inplace=True
ECom_Data.drop(columns=['product_specifications', 'description'], inplace=True)

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
# Get the number of unique brands
num_unique_brands = ECom_Data['Brand'].nunique()

print("Number of unique brands:", num_unique_brands)
# Out:
# Number of unique brands: 2484

# %% [markdown]
# ### Ans 3 b)

# %%
# Calculate the average product rating within each brand
brand_avg_rating = ECom_Data.groupby('Brand')['product_rating'].mean()

print(brand_avg_rating)
# Out:
# Brand
# 1OAK           1.500000
# 3A AUTOCARE    3.268293
# 3D MAT         3.000000
# 3KFACTORY      2.000000
# 4D             3.600000
#                  ...
# ZORDEN         4.000000
# ZOSIGN         3.400000
# ZRESTHA        1.000000
# ZYXEL          3.333333
#  TARKAN        5.000000
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# ### Ans 4 a)

# %%
# Group by product_main_category and count the number of items ordered in each category
category_counts = ECom_Data['product_main_category'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar')
plt.title('Count of Items Ordered for Each Product Main Category')
plt.xlabel('Product Main Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ans 4 b)

# %%
# Find the product main categories with the maximum and minimum orders
max_category = category_counts.idxmax()
min_category = category_counts.idxmin()

print("Product main category with maximum orders:", max_category)
print("Product main category with minimum orders:", min_category)
# Out:
# Product main category with maximum orders: Clothing
# Product main category with minimum orders: Wearable Smart Devices

# %% [markdown]
# ### Ans 4 c)

# %%
# Get the top 5 product main categories in descending order
top_categories = category_counts.nlargest(5)

print("Top 5 product main categories in descending order:")
print(top_categories)
# Out:
# Top 5 product main categories in descending order:
# product_main_category
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: count, dtype: int64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
# Define function to calculate revenue based on final price
def calculate_revenue(final_price):
    if final_price > 600:
        return final_price * 0.25
    elif 350 < final_price <= 600:
        return final_price * 0.15
    elif 100 < final_price <= 350:
        return final_price * 0.10
    else:
        return final_price * 0.05

# Calculate final price for each order
ECom_Data['final_price'] = ECom_Data['retail_price'] - ECom_Data['discounted_price']# * (ECom_Data['discounted_price']/100)

# Calculate revenue for each order
ECom_Data['revenue'] = ECom_Data['final_price'].apply(calculate_revenue)

# Calculate total revenue generated by the e-commerce company
total_revenue = ECom_Data['revenue'].sum()

print("Total revenue generated by the e-commerce company:", total_revenue)
# Out:
# Total revenue generated by the e-commerce company: 1785457.55

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
# Calculate BrandRevenue for each order
ECom_Data['BrandRevenue'] = ECom_Data['final_price'] - ECom_Data['revenue']

# Group by brand and sum up BrandRevenue for each brand
brand_revenue = ECom_Data.groupby('Brand')['BrandRevenue'].sum()

# Sort the brands based on total revenue in descending order
top_10_brands = brand_revenue.nlargest(10)

print("Top 10 brands with maximum revenue:")
print(top_10_brands)
# Out:
# Top 10 brands with maximum revenue:
# Brand
# ALLURE AUTO      981973.50
# THELOSTPUPPY     287100.00
# SLIM             202029.95
# GAGA             191581.75
# REGULAR          122373.40
# ENTHOPIA          96150.00
# HUGME.FASHION     74013.75
# SPEEDWAV          71701.55
# BLACK             66553.20
# LAPGUARD          56662.50
# Name: BrandRevenue, dtype: float64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
# Create a figure and axis
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Draw boxplot for retail_price
axs[0].boxplot(ECom_Data['retail_price'])
axs[0].set_title('Boxplot of Retail Price')
axs[0].set_ylabel('Price')

# Draw boxplot for discounted_price
axs[1].boxplot(ECom_Data['discounted_price'])
axs[1].set_title('Boxplot of Discounted Price')
axs[1].set_ylabel('Price')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ans 7 b)

# %%
#Yes

# %% [markdown]
# ### Ans 7 c)

# %%
# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(ECom_Data['retail_price'], ECom_Data['discounted_price'], alpha=0.5)
plt.title('Scatter Plot of Retail Price vs Discounted Price')
plt.xlabel('Retail Price')
plt.ylabel('Discounted Price')
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
# Group data by Brand and calculate aggregated values
brand_info = ECom_Data.groupby('Brand').agg({
    'product_unique ID': 'count',                      # Total number of orders placed per Brand
    'retail_price': 'sum',                    # Total retail price per Brand
    'discounted_price': 'sum',                # Total discounted price per Brand
    'BrandRevenue': 'sum'                     # Total BrandRevenue generated per Brand
}).reset_index()                              # Reset index to make 'Brand' a column

# Rename columns for clarity
brand_info.columns = ['Brand', 'TotalOrders', 'TotalRetailPrice', 'TotalDiscountedPrice', 'TotalBrandRevenue']

# Create pairplot
sns.pairplot(brand_info[['TotalOrders', 'TotalRetailPrice', 'TotalDiscountedPrice', 'TotalBrandRevenue']])
plt.title('Pairplot of Brand-Specific Information')
plt.show()

# Display the new DataFrame
print("New DataFrame with Brand-specific information:")
print(brand_info)
# Out:
# C:\Users\HP\.conda\envs\fin\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\.conda\envs\fin\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\.conda\envs\fin\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
# Convert 'order_date' column to datetime format
ECom_Data['Order_Date'] = pd.to_datetime(ECom_Data['Order_Date'])

# Extract month and year from 'order_date'
ECom_Data['month_year'] = ECom_Data['Order_Date'].dt.to_period('M')

# Group data by region and month_year, and calculate total revenue
region_monthly_revenue = ECom_Data.groupby(['Region', 'month_year'])['revenue'].sum().reset_index()

# Sort 'month_year'
region_monthly_revenue.sort_values(by='month_year', inplace=True)

# Plot line plot for each region separately
regions = region_monthly_revenue['Region'].unique()
plt.figure(figsize=(10, 6))
for region in regions:
    region_data = region_monthly_revenue[region_monthly_revenue['Region'] == region]
    plt.plot(region_data['month_year'].astype(str), region_data['revenue'], label=region)

plt.title('Monthly Revenue of E-Commerce Company for Each Region')
plt.xlabel('Month-Year')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ans 9 b)

# %%
# Determine the best and worst performing months for each region
best_months = region_monthly_revenue.groupby('Region').apply(lambda x: x.loc[x['revenue'].idxmax()])
worst_months = region_monthly_revenue.groupby('Region').apply(lambda x: x.loc[x['revenue'].idxmin()])

# Plot line plot for each region separately
regions = region_monthly_revenue['Region'].unique()
plt.figure(figsize=(12, 8))
for region in regions:
    region_data = region_monthly_revenue[region_monthly_revenue['Region'] == region]
    plt.plot(region_data['month_year'].astype(str), region_data['revenue'], label=region)

# Highlight best performing months
for idx, row in best_months.iterrows():
    plt.scatter(str(row['month_year']), row['revenue'], color='green', marker='o', label=f'Best: {row["Region"]}')

# Highlight worst performing months
for idx, row in worst_months.iterrows():
    plt.scatter(str(row['month_year']), row['revenue'], color='red', marker='x', label=f'Worst: {row["Region"]}')

plt.title('Monthly Revenue of E-Commerce Company for Each Region')
plt.xlabel('Month-Year')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7320\986716540.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_months = region_monthly_revenue.groupby('Region').apply(lambda x: x.loc[x['revenue'].idxmax()])
# C:\Users\HP\AppData\Local\Temp\ipykernel_7320\986716540.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
